# %% [markdown]
# # Multimodal Topic Analysis

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
from glob import glob

# Define path to TFRecord files
tfrecord_folder = "../../severity_data/image_files/"  # Adjust if needed

# Find all TFRecord files recursively
tfrecord_files = glob(os.path.join(tfrecord_folder, "**/*.tfrecord"), recursive=True)

# Define feature description for parsing TFRecords
feature_description = {
    "image/id": tf.io.FixedLenFeature([], tf.string),   # DICOM file path
    "embedding": tf.io.VarLenFeature(tf.float32),       # Image embedding
}

# Function to extract image embeddings from a TFRecord file
def extract_embeddings_from_tfrecord(tfrecord_path):
    dataset = tf.data.TFRecordDataset([tfrecord_path])
    dicom_ids = []
    embeddings = []

    for raw_record in dataset:
        parsed_example = tf.io.parse_single_example(raw_record, feature_description)

        # Extract DICOM path and ID
        dicom_path = parsed_example["image/id"].numpy().decode("utf-8")
        dicom_id = dicom_path.split("/")[-1].replace(".dcm", "")  # Extract filename without extension

        # Extract image embedding
        embedding = tf.sparse.to_dense(parsed_example["embedding"]).numpy()

        dicom_ids.append(dicom_id)
        embeddings.append(embedding.tolist())

    return dicom_ids, embeddings

# Process all TFRecord files
all_dicom_ids = []
all_embeddings = []

for tfrecord_file in tfrecord_files:
    dicom_ids, embeddings = extract_embeddings_from_tfrecord(tfrecord_file)
    all_dicom_ids.extend(dicom_ids)
    all_embeddings.extend(embeddings)

# Convert to DataFrame
image_embeddings_df = pd.DataFrame({"dicom_id": all_dicom_ids, "embedding": all_embeddings})

# Save extracted embeddings to CSV
image_embeddings_df.to_csv("image_embeddings.csv", index=False)

print("Extracted image embeddings saved to image_embeddings.csv!")
# Out:
# 2025-02-13 01:35:48.911263: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:35:48.967862: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:35:49.055560: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:35:49.238009: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:35:49.555391: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:35:50.147550: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:35:51.324321: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:35:53.892859: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:35:58.545456: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:36:08.023140: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:36:27.770205: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:37:05.623001: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:38:21.462250: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:41:05.802668: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:46:19.892976: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2025-02-13 01:57:47.691075: I tensorflow/core/framework/local_rendezvous.cc:405] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas as pd
import numpy as np

# Load datasets
image_embeddings_df = pd.read_csv("../../images/image_embeddings.csv")
text_embeddings_df = pd.read_csv("../NER_embeddings/pneumonia_type/radgraph_with_embeddings.csv")

# Merge datasets on 'dicom_id'
merged_df = pd.merge(text_embeddings_df, image_embeddings_df[['dicom_id', 'embedding']], on='dicom_id', suffixes=('_text', '_image'))

# Convert embeddings from string to list of floats
merged_df['embedding_text'] = merged_df['embedding_text'].apply(lambda x: np.array(eval(x)))
merged_df['embedding_image'] = merged_df['embedding_image'].apply(lambda x: np.array(eval(x)))

# Concatenate text and image embeddings to create multimodal embeddings
merged_df['embedding_multimodal'] = merged_df.apply(lambda row: np.concatenate([row['embedding_text'], row['embedding_image']]), axis=1)

# Extract final multimodal embeddings for BERTopic
multimodal_embeddings = np.vstack(merged_df['embedding_multimodal'].values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/gd/p6nf_1w11938t89t0bj2r9lc0000gn/T/ipykernel_86938/246552367.py in ?()
#      12 merged_df['embedding_text'] = merged_df['embedding_text'].apply(lambda x: np.array(eval(x)))
#      13 merged_df['embedding_image'] = merged_df['embedding_image'].apply(lambda x: np.array(eval(x)))
#      14
#      15 # Concatenate text and image embeddings to create multimodal embeddings
# ---> 16 merged_df['embedding_multimodal'] = merged_df.apply(lambda row: np.concatenate([row['embedding_text'], row['embedding_image']]), axis=1)
#      17
#      18 # Extract final multimodal embeddings for BERTopic
#      19 multimodal_embeddings = np.vstack(merged_df['embedding_multimodal'].values)
#
# ~/Documents/DATATHON/nusdatathon2024/.venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4297             self._setitem_frame(key, value)
#    4298         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4299             self._setitem_array(key, value)
#    4300         elif isinstance(value, DataFrame):
# -> 4301             self._set_item_frame_value(key, value)
#    4302         elif (
#    4303             is_list_like(value)
#    4304             and not self.columns.is_unique
#
# ~/Documents/DATATHON/nusdatathon2024/.venv/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, key, value)
#    4455
#    4456             return self.isetitem(locs, value)
#    4457
#    4458         if len(value.columns) > 1:
# -> 4459             raise ValueError(
#    4460                 "Cannot set a DataFrame with multiple columns to the single "
#    4461                 f"column {key}"
#    4462             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column embedding_multimodal

# %%
merged_df
# Out:
#       Unnamed: 0.1  subject_id_x   hadm_id  study_id  \
# 0                1      18110461  20001947  57106576
# 1                6      15447063  20009511  52444794
# 2                8      13243522  20013465  58791719
# 3                9      11423061  20014114  51779043
# 4               10      15379716  20015580  58785779
# ...            ...           ...       ...       ...
# 2591          4435      14236258  29989743  58255867
# 2592          4437      10623647  29991969  59289169
# 2593          4438      15116068  29993812  55182265
# 2594          4439      17025867  29996361  50696726
# 2595          4441      13478841  29999498  58035940
#
#                                           dicom_id pneumonia_type  Severe  \
# 0     1f239460-e00a31a5-81bdb260-f2929be7-f7cb2f7d      bacterial   False
# 1     82d06e5f-4f17e47a-3a96a851-d9454252-862ff5be      bacterial   False
# 2     fc215cad-d1060eb4-32e74e2e-15e2c40b-d01e66db      bacterial   False
# 3     9b1832b0-9cf4f257-fd4bbb42-06957578-0bf69814      bacterial    True
# 4     120b1593-d73e54d8-6d999909-ce1d93ce-d3b26f46      bacterial   False
# ...                                            ...            ...     ...
# 2591  0f33dea2-1c4e6245-7b21b568-ef0299e9-03c0863a      bacterial   False
# 2592  f47aa7aa-8461e734-cc03c9ac-f152661b-4700bd0c      bacterial   False
# 2593  65d1408e-bc59a65c-0be0fa6d-fb54b613-45abd8c1      bacterial   False
# 2594  99011231-5f716ee8-5e61eadd-447b48c4-4ec5255a      bacterial   False
# 2595  211b69be-01ae57d7-0774634f-18585752-f5d74b64      bacterial    True
#
#       Unnamed: 0  subject_id_y  \
# 0           3906      18110461
# 1           2557      15447063
# 2           1530      13243522
# 3            670      11423061
# 4           2511      15379716
# ...          ...           ...
# 2591        1992      14236258
# 2592         287      10623647
# 2593        2406      15116068
# 2594        3357      17025867
# 2595        1635      13478841
#
#                                             report_path  ...  \
# 0     ../../../severity_data/report_files/p18/p18110...  ...
# 1     ../../../severity_data/report_files/p15/p15447...  ...
# 2     ../../../severity_data/report_files/p13/p13243...  ...
# 3     ../../../severity_data/report_files/p11/p11423...  ...
# 4     ../../../severity_data/report_files/p15/p15379...  ...
# ...                                                 ...  ...
# 2591  ../../../severity_data/report_files/p14/p14236...  ...
# 2592  ../../../severity_data/report_files/p10/p10623...  ...
# 2593  ../../../severity_data/report_files/p15/p15116...  ...
# 2594  ../../../severity_data/report_files/p17/p17025...  ...
# 2595  ../../../severity_data/report_files/p13/p13478...  ...
#
#                                                findings  \
# 0     cardiac silhouette size is normal. mediastinal...
# 1     mild cardiomegaly has been stable compared to ...
# 2     right chest wall port-a-cath ends at the cavoa...
# 3     low lung volumes limit assessment of the lung ...
# 4                                                   NaN
# ...                                                 ...
# 2591  vague opacity projecting over the right mid/lo...
# 2592  bilateral patchy pulmonary opacities appear sl...
# 2593  extensive bronchiectasis is again noted in the...
# 2594                                                NaN
# 2595  ap and lateral views of the chest are compared...
#
#                                              impression has_comparison  \
# 0     findings concerning for multifocal pneumonia. ...           True
# 1     interval increase in consolidation at the left...          False
# 2     chronic changes of cystic fibrosis as describe...           True
# 3     low lung volumes limit assessment of the lung ...           True
# 4     stable lingular and increased right middle lob...           True
# ...                                                 ...            ...
# 2591  vague right mid/lower opacity, nonspecific the...           True
# 2592  patchy bilateral mid to lower lung opacities a...           True
# 2593  extensive bilateral bronchiectasis, with super...           True
# 2594  1. increase in density of a right lower and mi...           True
# 2595  no definite acute cardiopulmonary process base...          False
#
#      report_length                                      radgraph_text  \
# 0              645  cardiac silhouette size is normal. mediastinal...
# 1              806  mild cardiomegaly has been stable compared to ...
# 2             1136  right chest wall port-a-cath ends at the cavoa...
# 3              685  low lung volumes limit assessment of the lung ...
# 4              600                                                NaN
# ...            ...                                                ...
# 2591           695  vague opacity projecting over the right mid/lo...
# 2592          1760  bilateral patchy pulmonary opacities appear sl...
# 2593          1100  extensive bronchiectasis is again noted in the...
# 2594           649                                                NaN
# 2595           550  ap and lateral views of the chest are compared...
#
#                                                extracts  \
# 0     {'0': {'text': 'cardiac silhouette size is nor...
# 1     {'0': {'text': 'mild cardiomegaly has been sta...
# 2     {'0': {'text': 'right chest wall port - a - ca...
# 3     {'0': {'text': 'low lung volumes limit assessm...
# 4     {'0': {'text': 'nan', 'entities': {}, 'data_so...
# ...                                                 ...
# 2591  {'0': {'text': 'vague opacity projecting over ...
# 2592  {'0': {'text': 'bilateral patchy pulmonary opa...
# 2593  {'0': {'text': 'extensive bronchiectasis is ag...
# 2594  {'0': {'text': 'nan', 'entities': {}, 'data_so...
# 2595  {'0': {'text': 'ap and lateral views of the ch...
#
#                                      processed_radgraph  \
# 0     cardiac is an anatomy. silhouette modifies car...
# 1     mild modifies cardiomegaly. cardiomegaly is an...
# 2     right modifies wall. chest modifies wall. wall...
# 3     low is located at volumes. lung is an anatomy....
# 4                                                   NaN
# ...                                                 ...
# 2591  vague modifies opacity. opacity is located at ...
# 2592  bilateral modifies pulmonary. patchy modifies ...
# 2593  extensive modifies bronchiectasis. bronchiecta...
# 2594                                                NaN
# 2595  low is located at lung. lung is an anatomy. vo...
#
#                                          embedding_text  \
# 0     [0.03332185745239258, -0.005314456298947334, -...
# 1     [0.0257903840392828, -0.0005293460562825203, 0...
# 2     [0.038594670593738556, -0.015855595469474792, ...
# 3     [0.030176309868693352, -0.024805540218949318, ...
# 4     [-0.035868603736162186, -0.13423331081867218, ...
# ...                                                 ...
# 2591  [0.04184424504637718, -0.01704668439924717, 0....
# 2592  [0.03257104381918907, -0.026108980178833008, -...
# 2593  [0.03614714369177818, -0.008272165432572365, -...
# 2594  [-0.035868603736162186, -0.13423331081867218, ...
# 2595  [0.02125793695449829, -0.008776791393756866, 0...
#
#                                         embedding_image  \
# 0     [-1.0478514432907104, -0.9893836975097656, 0.9...
# 1     [0.14750519394874573, -0.8777117133140564, 1.2...
# 2     [-0.6212253570556641, -0.6505540609359741, 1.1...
# 3     [-0.6631452441215515, -0.5168229341506958, 1.0...
# 4     [-0.08448687195777893, -1.0461037158966064, 1....
# ...                                                 ...
# 2591  [-0.12456560134887695, -0.08151178061962128, 1...
# 2592  [-0.27105075120925903, -0.9785194993019104, 1....
# 2593  [-0.37828612327575684, -0.8936127424240112, 0....
# 2594  [0.11463172733783722, -0.3663841485977173, 0.7...
# 2595  [0.04033620283007622, -0.33555862307548523, 1....
#
#                                    embedding_multimodal
# 0     [0.03332185745239258, -0.005314456298947334, -...
# 1     [0.0257903840392828, -0.0005293460562825203, 0...
# 2     [0.038594670593738556, -0.015855595469474792, ...
# 3     [0.030176309868693352, -0.024805540218949318, ...
# 4     [-0.035868603736162186, -0.13423331081867218, ...
# ...                                                 ...
# 2591  [0.04184424504637718, -0.01704668439924717, 0....
# 2592  [0.03257104381918907, -0.026108980178833008, -...
# 2593  [0.03614714369177818, -0.008272165432572365, -...
# 2594  [-0.035868603736162186, -0.13423331081867218, ...
# 2595  [0.02125793695449829, -0.008776791393756866, 0...
#
# [2596 rows x 25 columns]

# %%
topic_model.visualize_barchart(top_n_topics=100)
