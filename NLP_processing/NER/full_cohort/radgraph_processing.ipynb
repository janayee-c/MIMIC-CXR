# %% [markdown]
# # Radgraph Processing
#
# Turning extracts into discernable form for BERTopic and Processing

# %%
import torch 
import pandas as pd 

csv_radgraph_path = "./cohort_ner_database.csv"
tensor_radgraph_path = "./cohort_ner_database.pt"

radgraph_tensor = torch.load(tensor_radgraph_path) # already a df 
sample = radgraph_tensor.iloc[1]['extracts']
sample
# Out:
# /var/folders/gd/p6nf_1w11938t89t0bj2r9lc0000gn/T/ipykernel_79159/825503843.py:7: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   radgraph_tensor = torch.load(tensor_radgraph_path) # already a df
# {'0': {'text': 'heart size is mildly enlarged . there is mild unfolding of the thoracic aorta . cardiomediastinal silhouette and hilar contours are otherwise unremarkable . there is mild bibasilar atelectasis . lungs are otherwise clear . pleural surfaces are clear without effusion or pneumothorax . focus of air seen under the right hemidiaphragm , likely represents colonic interposition . no acute cardiopulmonary abnormality .',
#   'entities': {'1': {'tokens': 'heart',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 0,
#     'end_ix': 0,
#     'relations': []},
#    '2': {'tokens': 'size',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 1,
#     'end_ix': 1,
#     'relations': [['modify', '1']]},
#    '3': {'tokens': 'mildly',
#     'label': 'Observation::definitely present',
#     'start_ix': 3,
#     'end_ix': 3,
#     'relations': [['modify', '4']]},
#    '4': {'tokens': 'enlarged',
#     'label': 'Observation::definitely present',
#     'start_ix': 4,
#     'end_ix': 4,
#     'relations': [['located_at', '1']]},
#    '5': {'tokens': 'mild',
#     'label': 'Observation::definitely present',
#     'start_ix': 8,
#     'end_ix': 8,
#     'relations': [['modify', '6']]},
#    '6': {'tokens': 'unfolding',
#     'label': 'Observation::definitely present',
#     'start_ix': 9,
#     'end_ix': 9,
#     'relations': [['located_at', '8']]},
#    '7': {'tokens': 'thoracic',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 12,
#     'end_ix': 12,
#     'relations': [['modify', '8']]},
#    '8': {'tokens': 'aorta',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 13,
#     'end_ix': 13,
#     'relations': []},
#    '9': {'tokens': 'cardiomediastinal',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 15,
#     'end_ix': 15,
#     'relations': []},
#    '10': {'tokens': 'silhouette',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 16,
#     'end_ix': 16,
#     'relations': [['modify', '9']]},
#    '11': {'tokens': 'hilar',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 18,
#     'end_ix': 18,
#     'relations': []},
#    '12': {'tokens': 'contours',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 19,
#     'end_ix': 19,
#     'relations': [['modify', '11']]},
#    '13': {'tokens': 'unremarkable',
#     'label': 'Observation::definitely present',
#     'start_ix': 22,
#     'end_ix': 22,
#     'relations': [['located_at', '9'], ['located_at', '11']]},
#    '14': {'tokens': 'mild',
#     'label': 'Observation::definitely present',
#     'start_ix': 26,
#     'end_ix': 26,
#     'relations': [['modify', '16']]},
#    '15': {'tokens': 'bibasilar',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 27,
#     'end_ix': 27,
#     'relations': []},
#    '16': {'tokens': 'atelectasis',
#     'label': 'Observation::definitely present',
#     'start_ix': 28,
#     'end_ix': 28,
#     'relations': [['located_at', '15']]},
#    '17': {'tokens': 'lungs',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 30,
#     'end_ix': 30,
#     'relations': []},
#    '18': {'tokens': 'clear',
#     'label': 'Observation::definitely present',
#     'start_ix': 33,
#     'end_ix': 33,
#     'relations': [['located_at', '17']]},
#    '19': {'tokens': 'pleural',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 35,
#     'end_ix': 35,
#     'relations': []},
#    '20': {'tokens': 'surfaces',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 36,
#     'end_ix': 36,
#     'relations': [['modify', '19']]},
#    '21': {'tokens': 'clear',
#     'label': 'Observation::definitely present',
#     'start_ix': 38,
#     'end_ix': 38,
#     'relations': [['located_at', '19']]},
#    '22': {'tokens': 'effusion',
#     'label': 'Observation::definitely absent',
#     'start_ix': 40,
#     'end_ix': 40,
#     'relations': [['located_at', '19']]},
#    '23': {'tokens': 'pneumothorax',
#     'label': 'Observation::definitely absent',
#     'start_ix': 42,
#     'end_ix': 42,
#     'relations': []},
#    '24': {'tokens': 'air',
#     'label': 'Observation::definitely present',
#     'start_ix': 46,
#     'end_ix': 46,
#     'relations': [['located_at', '27'], ['located_at', '28']]},
#    '25': {'tokens': 'under',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 48,
#     'end_ix': 48,
#     'relations': [['modify', '27']]},
#    '26': {'tokens': 'right',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 50,
#     'end_ix': 50,
#     'relations': [['modify', '27']]},
#    '27': {'tokens': 'hemidiaphragm',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 51,
#     'end_ix': 51,
#     'relations': []},
#    '28': {'tokens': 'colonic',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 55,
#     'end_ix': 55,
#     'relations': []},
#    '29': {'tokens': 'interposition',
#     'label': 'Observation::uncertain',
#     'start_ix': 56,
#     'end_ix': 56,
#     'relations': [['located_at', '28']]},
#    '30': {'tokens': 'acute',
#     'label': 'Observation::definitely absent',
#     'start_ix': 59,
#     'end_ix': 59,
#     'relations': [['modify', '32']]},
#    '31': {'tokens': 'cardiopulmonary',
#     'label': 'Anatomy::definitely present',
#     'start_ix': 60,
#     'end_ix': 60,
#     'relations': []},
#    '32': {'tokens': 'abnormality',
#     'label': 'Observation::definitely absent',
#     'start_ix': 61,
#     'end_ix': 61,
#     'relations': [['located_at', '31']]}},
#   'data_source': None,
#   'data_split': 'inference'}}

# %%
radgraph_tensor
# Out:
#       study_id  subject_id                                        report_path  \
# 0     51967283    10000980  ../../../severity_data/report_files/p10/p10000...
# 1     54369281    10001884  ../../../severity_data/report_files/p10/p10001...
# 2     58838312    10002428  ../../../severity_data/report_files/p10/p10002...
# 3     52139270    10003502  ../../../severity_data/report_files/p10/p10003...
# 4     57662923    10004322  ../../../severity_data/report_files/p10/p10004...
# ...        ...         ...                                                ...
# 5545  51053775    19941135  ../../../severity_data/report_files/p19/p19941...
# 5546  52939041    19951239  ../../../severity_data/report_files/p19/p19951...
# 5547  52809931    19963862  ../../../severity_data/report_files/p19/p19963...
# 5548  53101264    19992525  ../../../severity_data/report_files/p19/p19992...
# 5549  50244700    19992875  ../../../severity_data/report_files/p19/p19992...
#
#                                               full_text         examination  \
# 0     FINAL REPORT INDICATION: [REMOVED]-year-old fe...                 NaN
# 1     FINAL REPORT EXAMINATION: Chest radiograph IND...    chest radiograph
# 2     FINAL REPORT PORTABLE CHEST: [REMOVED]. HISTOR...                 NaN
# 3     FINAL REPORT HISTORY: Nausea and chllls. TECHN...                 NaN
# 4     WET READ: [REMOVED] [REMOVED] 2:03 PM Streaky ...  chest (pa and lat)
# ...                                                 ...                 ...
# 5545  FINAL REPORT EXAMINATION: CHEST (PA AND LAT) I...  chest (pa and lat)
# 5546  WET READ: [REMOVED] [REMOVED] [REMOVED] 6:49 P...                 NaN
# 5547  FINAL REPORT HISTORY: Pneumonia for 9 days, ev...                 NaN
# 5548  FINAL REPORT CHEST RADIOGRAPH PERFORMED ON [RE...                 NaN
# 5549  WET READ: [REMOVED] [REMOVED] [REMOVED] 12:22 ...   chest radiograph.
#
#                                              indication  \
# 0     [REMOVED]-year-old female with shortness of br...
# 1                                              dyspnea.
# 2                                                   NaN
# 3                                                   NaN
# 4     history: [REMOVED]m with 2 weeks productive co...
# ...                                                 ...
# 5545                     history: [REMOVED]f with cough
# 5546  history: [REMOVED]f with fever and cough // r/...
# 5547                                                NaN
# 5548                                                NaN
# 5549  history: [REMOVED]m with shortness of breath? ...
#
#                                         technique  \
# 0                                             NaN
# 1              ap and lateral views of the chest.
# 2                                             NaN
# 3         frontal and lateral views of the chest.
# 4     pa and lateral views of the chest provided.
# ...                                           ...
# 5545                         chest pa and lateral
# 5546                         chest pa and lateral
# 5547      frontal and lateral views of the chest.
# 5548                                          NaN
# 5549                         chest pa and lateral
#
#                                              comparison  \
# 0     chest radiograph from [REMOVED] and [REMOVED]....
# 1                                             [REMOVED]
# 2                                                   NaN
# 3                                            [REMOVED].
# 4                     chest radiograph dated [REMOVED].
# ...                                                 ...
# 5545                                              none.
# 5546                                     none available
# 5547                                              none.
# 5548  chest radiograph dated [REMOVED]. clinical his...
# 5549                                          [REMOVED]
#
#                                                findings  \
# 0                                                   NaN
# 1     heart size is mildly enlarged. there is mild u...
# 2     single portable view of the chest is compared ...
# 3     there are moderate bilateral pleural effusions...
# 4     subtle streaky opacity in the left lower lobe ...
# ...                                                 ...
# 5545  cardiac silhouette size is normal. mediastinal...
# 5546  pa and lateral chest radiograph demonstrates a...
# 5547  there is a consolidation in the right lower lo...
# 5548  pa and lateral views of the chest were provide...
# 5549  multiple healed rib fractures are re- demonstr...
#
#                                              impression  has_comparison  \
# 0     right upper lobe pneumonia or mass. however, g...            True
# 1                 no acute cardiopulmonary abnormality.            True
# 2     no significant interval change with bilateral ...           False
# 3     bilateral pleural effusions, cardiomegaly and ...            True
# 4     streaky left lobe opacity may reflect atelecta...            True
# ...                                                 ...             ...
# 5545  focal ill-defined opacity in the left lung bas...            True
# 5546                        right upper lobe pneumonia.            True
# 5547  right lower lobe pneumonia. follow-up to resol...            True
# 5548  band-like opacity in the right lower lung coul...            True
# 5549  an opacity at the cardiac apex is concerning f...            True
#
#       report_length                                      radgraph_text  \
# 0               797                                                nan
# 1               560  heart size is mildly enlarged. there is mild u...
# 2               761  single portable view of the chest is compared ...
# 3               648  there are moderate bilateral pleural effusions...
# 4              1345  subtle streaky opacity in the left lower lobe ...
# ...             ...                                                ...
# 5545            694  cardiac silhouette size is normal. mediastinal...
# 5546            585  pa and lateral chest radiograph demonstrates a...
# 5547            673  there is a consolidation in the right lower lo...
# 5548            792  pa and lateral views of the chest were provide...
# 5549            621  multiple healed rib fractures are re- demonstr...
#
#                                                extracts
# 0     {'0': {'text': 'nan', 'entities': {}, 'data_so...
# 1     {'0': {'text': 'heart size is mildly enlarged ...
# 2     {'0': {'text': 'single portable view of the ch...
# 3     {'0': {'text': 'there are moderate bilateral p...
# 4     {'0': {'text': 'subtle streaky opacity in the ...
# ...                                                 ...
# 5545  {'0': {'text': 'cardiac silhouette size is nor...
# 5546  {'0': {'text': 'pa and lateral chest radiograp...
# 5547  {'0': {'text': 'there is a consolidation in th...
# 5548  {'0': {'text': 'pa and lateral views of the ch...
# 5549  {'0': {'text': 'multiple healed rib fractures ...
#
# [5550 rows x 14 columns]

# %% [markdown]
# ## Radgraph Processor - Entities and Relations

# %%
import json
import pandas as pd

def process_radgraph_extracts(extracts_json):
    """
    Converts RadGraph 'extracts' into structured clinical text for BERTopic.

    Args:
    - extracts_json (str or dict): RadGraph JSON stored in the 'extracts' column.

    Returns:
    - str: Reformatted text with preserved relations.
    """
    if isinstance(extracts_json, str):
        extracts_json = json.loads(extracts_json)  # Convert string to dict if needed

    # Extract only the first key (assumed report ID or study ID)
    first_key = list(extracts_json.keys())[0]
    radgraph_data = extracts_json[first_key]

    entities = radgraph_data.get("entities", {})
    sentences = []
    
    entity_map = {eid: entity["tokens"] for eid, entity in entities.items()}  # ID → Text map

    # Convert relations into readable text
    for eid, entity in entities.items():
        entity_text = entity["tokens"]
        entity_label = entity["label"].split("::")[0]  # Keep main category (Anatomy, Observation)
        relations = entity.get("relations", [])

        # Base description of the entity
        entity_sentence = f"{entity_text} is an {entity_label.lower()}."
        
        # Add relational information
        for rel in relations:
            relation_type, target_eid = rel
            target_text = entity_map.get(target_eid, "")
            
            if relation_type == "modify":
                entity_sentence = f"{entity_text} modifies {target_text}."
            elif relation_type == "located_at":
                entity_sentence = f"{entity_text} is located at {target_text}."
            elif relation_type == "associated_with":
                entity_sentence = f"{entity_text} is associated with {target_text}."
        
        sentences.append(entity_sentence)

    return " ".join(sentences)

# Apply processing to the entire 'extracts' column
# Apply to a sample (radgraph extract for the first study)
sample_extract = process_radgraph_extracts(radgraph_tensor['extracts'][0])
print(sample_extract)

radgraph_tensor["processed_radgraph"] = radgraph_tensor["extracts"].apply(process_radgraph_extracts)
radgraph_tensor
# Out:
#       study_id  subject_id                                        report_path  \
# 0     51967283    10000980  ../../../severity_data/report_files/p10/p10000...
# 1     54369281    10001884  ../../../severity_data/report_files/p10/p10001...
# 2     58838312    10002428  ../../../severity_data/report_files/p10/p10002...
# 3     52139270    10003502  ../../../severity_data/report_files/p10/p10003...
# 4     57662923    10004322  ../../../severity_data/report_files/p10/p10004...
# ...        ...         ...                                                ...
# 5545  51053775    19941135  ../../../severity_data/report_files/p19/p19941...
# 5546  52939041    19951239  ../../../severity_data/report_files/p19/p19951...
# 5547  52809931    19963862  ../../../severity_data/report_files/p19/p19963...
# 5548  53101264    19992525  ../../../severity_data/report_files/p19/p19992...
# 5549  50244700    19992875  ../../../severity_data/report_files/p19/p19992...
#
#                                               full_text         examination  \
# 0     FINAL REPORT INDICATION: [REMOVED]-year-old fe...                 NaN
# 1     FINAL REPORT EXAMINATION: Chest radiograph IND...    chest radiograph
# 2     FINAL REPORT PORTABLE CHEST: [REMOVED]. HISTOR...                 NaN
# 3     FINAL REPORT HISTORY: Nausea and chllls. TECHN...                 NaN
# 4     WET READ: [REMOVED] [REMOVED] 2:03 PM Streaky ...  chest (pa and lat)
# ...                                                 ...                 ...
# 5545  FINAL REPORT EXAMINATION: CHEST (PA AND LAT) I...  chest (pa and lat)
# 5546  WET READ: [REMOVED] [REMOVED] [REMOVED] 6:49 P...                 NaN
# 5547  FINAL REPORT HISTORY: Pneumonia for 9 days, ev...                 NaN
# 5548  FINAL REPORT CHEST RADIOGRAPH PERFORMED ON [RE...                 NaN
# 5549  WET READ: [REMOVED] [REMOVED] [REMOVED] 12:22 ...   chest radiograph.
#
#                                              indication  \
# 0     [REMOVED]-year-old female with shortness of br...
# 1                                              dyspnea.
# 2                                                   NaN
# 3                                                   NaN
# 4     history: [REMOVED]m with 2 weeks productive co...
# ...                                                 ...
# 5545                     history: [REMOVED]f with cough
# 5546  history: [REMOVED]f with fever and cough // r/...
# 5547                                                NaN
# 5548                                                NaN
# 5549  history: [REMOVED]m with shortness of breath? ...
#
#                                         technique  \
# 0                                             NaN
# 1              ap and lateral views of the chest.
# 2                                             NaN
# 3         frontal and lateral views of the chest.
# 4     pa and lateral views of the chest provided.
# ...                                           ...
# 5545                         chest pa and lateral
# 5546                         chest pa and lateral
# 5547      frontal and lateral views of the chest.
# 5548                                          NaN
# 5549                         chest pa and lateral
#
#                                              comparison  \
# 0     chest radiograph from [REMOVED] and [REMOVED]....
# 1                                             [REMOVED]
# 2                                                   NaN
# 3                                            [REMOVED].
# 4                     chest radiograph dated [REMOVED].
# ...                                                 ...
# 5545                                              none.
# 5546                                     none available
# 5547                                              none.
# 5548  chest radiograph dated [REMOVED]. clinical his...
# 5549                                          [REMOVED]
#
#                                                findings  \
# 0                                                   NaN
# 1     heart size is mildly enlarged. there is mild u...
# 2     single portable view of the chest is compared ...
# 3     there are moderate bilateral pleural effusions...
# 4     subtle streaky opacity in the left lower lobe ...
# ...                                                 ...
# 5545  cardiac silhouette size is normal. mediastinal...
# 5546  pa and lateral chest radiograph demonstrates a...
# 5547  there is a consolidation in the right lower lo...
# 5548  pa and lateral views of the chest were provide...
# 5549  multiple healed rib fractures are re- demonstr...
#
#                                              impression  has_comparison  \
# 0     right upper lobe pneumonia or mass. however, g...            True
# 1                 no acute cardiopulmonary abnormality.            True
# 2     no significant interval change with bilateral ...           False
# 3     bilateral pleural effusions, cardiomegaly and ...            True
# 4     streaky left lobe opacity may reflect atelecta...            True
# ...                                                 ...             ...
# 5545  focal ill-defined opacity in the left lung bas...            True
# 5546                        right upper lobe pneumonia.            True
# 5547  right lower lobe pneumonia. follow-up to resol...            True
# 5548  band-like opacity in the right lower lung coul...            True
# 5549  an opacity at the cardiac apex is concerning f...            True
#
#       report_length                                      radgraph_text  \
# 0               797                                                nan
# 1               560  heart size is mildly enlarged. there is mild u...
# 2               761  single portable view of the chest is compared ...
# 3               648  there are moderate bilateral pleural effusions...
# 4              1345  subtle streaky opacity in the left lower lobe ...
# ...             ...                                                ...
# 5545            694  cardiac silhouette size is normal. mediastinal...
# 5546            585  pa and lateral chest radiograph demonstrates a...
# 5547            673  there is a consolidation in the right lower lo...
# 5548            792  pa and lateral views of the chest were provide...
# 5549            621  multiple healed rib fractures are re- demonstr...
#
#                                                extracts  \
# 0     {'0': {'text': 'nan', 'entities': {}, 'data_so...
# 1     {'0': {'text': 'heart size is mildly enlarged ...
# 2     {'0': {'text': 'single portable view of the ch...
# 3     {'0': {'text': 'there are moderate bilateral p...
# 4     {'0': {'text': 'subtle streaky opacity in the ...
# ...                                                 ...
# 5545  {'0': {'text': 'cardiac silhouette size is nor...
# 5546  {'0': {'text': 'pa and lateral chest radiograp...
# 5547  {'0': {'text': 'there is a consolidation in th...
# 5548  {'0': {'text': 'pa and lateral views of the ch...
# 5549  {'0': {'text': 'multiple healed rib fractures ...
#
#                                      processed_radgraph
# 0
# 1     heart is an anatomy. size modifies heart. mild...
# 2     enteric modifies tube. tube is an observation....
# 3     moderate modifies effusions. bilateral modifie...
# 4     subtle modifies opacity. streaky modifies opac...
# ...                                                 ...
# 5545  cardiac is an anatomy. silhouette modifies car...
# 5546  airspace modifies lobe. opacity is located at ...
# 5547  consolidation is located at lobe. right modifi...
# 5548  severe modifies dextroscoliosis. dextroscolios...
# 5549  multiple modifies fractures. healed modifies f...
#
# [5550 rows x 15 columns]

# %%
radgraph_tensor.to_csv('./processed_NER_extracts.csv')
torch.save(radgraph_tensor, './processed_NER_extracts.pt')

# %%
radgraph_tensor = pd.read_csv('./processed_NER_extracts.csv')
radgraph_tensor.iloc[1]['processed_radgraph']
# Out:
# 'heart is an anatomy. size modifies heart. mildly modifies enlarged. enlarged is located at heart. mild modifies unfolding. unfolding is located at aorta. thoracic modifies aorta. aorta is an anatomy. cardiomediastinal is an anatomy. silhouette modifies cardiomediastinal. hilar is an anatomy. contours modifies hilar. unremarkable is located at hilar. mild modifies atelectasis. bibasilar is an anatomy. atelectasis is located at bibasilar. lungs is an anatomy. clear is located at lungs. pleural is an anatomy. surfaces modifies pleural. clear is located at pleural. effusion is located at pleural. pneumothorax is an observation. air is located at colonic. under modifies hemidiaphragm. right modifies hemidiaphragm. hemidiaphragm is an anatomy. colonic is an anatomy. interposition is located at colonic. acute modifies abnormality. cardiopulmonary is an anatomy. abnormality is located at cardiopulmonary.'
